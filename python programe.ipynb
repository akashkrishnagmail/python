# %% [markdown]
# import numpy as np
# import pandas as pd

# %%
d1={'name':['akash','chandan','mayur','gururaj','deekshith','danajay','dennies','manish','merolin','deeksha'],
    'age':[22,10,22,20,33,22,44,33,22,20],
    'class':['MCA','MBA','MCOM','MCA','MBA','MCOM','MCA','MBA','MCOM','MCA'],
    'marks':[90,80,40,60,100,90,80,40,60,100]}
d1
# Out:
# {'name': ['akash',
#   'chandan',
#   'mayur',
#   'gururaj',
#   'deekshith',
#   'danajay',
#   'dennies',
#   'manish',
#   'merolin',
#   'deeksha'],
#  'age': [22, 10, 22, 20, 33, 22, 44, 33, 22, 20],
#  'class': ['MCA',
#   'MBA',
#   'MCOM',
#   'MCA',
#   'MBA',
#   'MCOM',
#   'MCA',
#   'MBA',
#   'MCOM',
#   'MCA'],
#  'marks': [90, 80, 40, 60, 100, 90, 80, 40, 60, 100]}

# %%
df=pd.DataFrame(d1)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7284/1573033215.py in <module>
# ----> 1 df=pd.DataFrame(d1)
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df['name']
# Out:
# 0        akash
# 1      chandan
# 2        mayur
# 3      gururaj
# 4    deekshith
# 5      danajay
# 6      dennies
# 7       manish
# 8      merolin
# 9      deeksha
# Name: name, dtype: object

# %%
df.head(8)
# Out:
#         name  age class  marks
# 0      akash   22   MCA     90
# 1    chandan   10   MBA     80
# 2      mayur   22  MCOM     40
# 3    gururaj   20   MCA     60
# 4  deekshith   33   MBA    100
# 5    danajay   22  MCOM     90
# 6    dennies   44   MCA     80
# 7     manish   33   MBA     40

# %%
df.tail(3)
# Out:
#       name  age class  marks
# 7   manish   33   MBA     40
# 8  merolin   22  MCOM     60
# 9  deeksha   20   MCA    100

# %%
df.to_csv('student.csv')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7284/3627053830.py in <module>
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
import numpy as np 
import pandas as pd

# %%
d1={'name':['akash','chandan','mayur','gururaj','deekshith','danajay','dennies','manish','merolin','deeksha'],
    'age':[22,10,22,20,33,22,44,33,22,20],
    'class':['MCA','MBA','MCOM','MCA','MBA','MCOM','MCA','MBA','MCOM','MCA'],
    'marks':[90,80,40,60,100,90,80,40,60,100]}

# %%
df=pd.DataFrame(d1)
df
# Out:
#         name  age class  marks
# 0      akash   22   MCA     90
# 1    chandan   10   MBA     80
# 2      mayur   22  MCOM     40
# 3    gururaj   20   MCA     60
# 4  deekshith   33   MBA    100
# 5    danajay   22  MCOM     90
# 6    dennies   44   MCA     80
# 7     manish   33   MBA     40
# 8    merolin   22  MCOM     60
# 9    deeksha   20   MCA    100

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# name     object
# age       int64
# class    object
# marks     int64
# dtype: object

# %%
de=df.copy()

# %%
de
# Out:
#         name  age class  marks
# 0      akash   22   MCA     90
# 1    chandan   10   MBA     80
# 2      mayur   22  MCOM     40
# 3    gururaj   20   MCA     60
# 4  deekshith   33   MBA    100
# 5    danajay   22  MCOM     90
# 6    dennies   44   MCA     80
# 7     manish   33   MBA     40
# 8    merolin   22  MCOM     60
# 9    deeksha   20   MCA    100

# %%
de.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
de.columns
# Out:
# Index(['name', 'age', 'class', 'marks'], dtype='object')

# %%
de.T
# Out:
#            0        1      2        3          4        5        6       7  \
# name   akash  chandan  mayur  gururaj  deekshith  danajay  dennies  manish
# age       22       10     22       20         33       22       44      33
# class    MCA      MBA   MCOM      MCA        MBA     MCOM      MCA     MBA
# marks     90       80     40       60        100       90       80      40
#
#              8        9
# name   merolin  deeksha
# age         22       20
# class     MCOM      MCA
# marks       60      100

# %%
de.sort_index(axis=0,ascending=False)
# Out:
#         name  age class  marks
# 9    deeksha   20   MCA    100
# 8    merolin   22  MCOM     60
# 7     manish   33   MBA     40
# 6    dennies   44   MCA     80
# 5    danajay   22  MCOM     90
# 4  deekshith   33   MBA    100
# 3    gururaj   20   MCA     60
# 2      mayur   22  MCOM     40
# 1    chandan   10   MBA     80
# 0      akash   22   MCA     90

# %%
de.loc[0,0]=420

# %%
de
# Out:
#         name  age class  marks      0
# 0      akash   22   MCA     90  420.0
# 1    chandan   10   MBA     80    NaN
# 2      mayur   22  MCOM     40    NaN
# 3    gururaj   20   MCA     60    NaN
# 4  deekshith   33   MBA    100    NaN
# 5    danajay   22  MCOM     90    NaN
# 6    dennies   44   MCA     80    NaN
# 7     manish   33   MBA     40    NaN
# 8    merolin   22  MCOM     60    NaN
# 9    deeksha   20   MCA    100    NaN

# %%
de.loc[8,"name"]='prakash'

# %%
de
# Out:
#         name  age class  marks      0
# 0      akash   22   MCA     90  420.0
# 1    chandan   10   MBA     80    NaN
# 2      mayur   22  MCOM     40    NaN
# 3    gururaj   20   MCA     60    NaN
# 4  deekshith   33   MBA    100    NaN
# 5    danajay   22  MCOM     90    NaN
# 6    dennies   44   MCA     80    NaN
# 7     manish   33   MBA     40    NaN
# 8    prakash   22  MCOM     60    NaN
# 9    deeksha   20   MCA    100    NaN

# %%
#readind the csv file
af=pd.read_csv("emp.csv")

# %%
#result of reading csv file
af
# Out:
#    Unnamed: 0       name   eno    salary   age
# 0           1      akash  E001  100000.0  20.0
# 1           2    chandan  E002  100001.0  21.0
# 2           3      mayur  E003       NaN  22.0
# 3           4    gururaj  E004  100003.0  23.0
# 4           5  deekshith  E005  100004.0   NaN
# 5           6    danajay  E006  100005.0  25.0
# 6           7    dennies   NaN  100006.0  26.0
# 7           8     manish  E008  100007.0  27.0
