# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("stud.csv")

# %%
data
# Out:
#    Sl_no      Name Qualification       Mobile    Adress
# 0      1     Akash           MCA  7.899858e+09  Kokkada
# 1      2   Prakash           MCA  7.899858e+09  KOKKADA
# 2      3    Suresh           MBA  7.899858e+09  KOKKADA
# 3      4    Ramesh          MCOM  7.899858e+09  KOKKADA
# 4      5     Jagga           MCA  7.899858e+09      NaN
# 5      6   Chandan           MBA  7.899858e+09      NaN
# 6      7    M ayur           MCA  7.899858e+09  Nelyadi
# 7      8     Rampa          MCOM  7.899858e+09   Puttur
# 8      9     Sompa           MMB           NaN    Sulya
# 9     10  Aythappa           BBM           NaN   Kadaba

# %%
data.head(8)
# Out:
#    Sl_no     Name Qualification       Mobile    Adress
# 0      1    Akash           MCA  7.899858e+09  Kokkada
# 1      2  Prakash           MCA  7.899858e+09  KOKKADA
# 2      3   Suresh           MBA  7.899858e+09  KOKKADA
# 3      4   Ramesh          MCOM  7.899858e+09  KOKKADA
# 4      5    Jagga           MCA  7.899858e+09      NaN
# 5      6  Chandan           MBA  7.899858e+09      NaN
# 6      7   M ayur           MCA  7.899858e+09  Nelyadi
# 7      8    Rampa          MCOM  7.899858e+09   Puttur

# %%
data.tail(7)
# Out:
#    Sl_no      Name Qualification       Mobile    Adress
# 3      4    Ramesh          MCOM  7.899858e+09  KOKKADA
# 4      5     Jagga           MCA  7.899858e+09      NaN
# 5      6   Chandan           MBA  7.899858e+09      NaN
# 6      7    M ayur           MCA  7.899858e+09  Nelyadi
# 7      8     Rampa          MCOM  7.899858e+09   Puttur
# 8      9     Sompa           MMB           NaN    Sulya
# 9     10  Aythappa           BBM           NaN   Kadaba

# %%
data.drop_duplicates(subset=["Name"])
# Out:
#    Sl_no      Name Qualification       Mobile    Adress
# 0      1     Akash           MCA  7.899858e+09  Kokkada
# 1      2   Prakash           MCA  7.899858e+09  KOKKADA
# 2      3    Suresh           MBA  7.899858e+09  KOKKADA
# 3      4    Ramesh          MCOM  7.899858e+09  KOKKADA
# 4      5     Jagga           MCA  7.899858e+09      NaN
# 5      6   Chandan           MBA  7.899858e+09      NaN
# 6      7    M ayur           MCA  7.899858e+09  Nelyadi
# 7      8     Rampa          MCOM  7.899858e+09   Puttur
# 8      9     Sompa           MMB           NaN    Sulya
# 9     10  Aythappa           BBM           NaN   Kadaba

# %%
data.isnull()
# Out:
#    Sl_no   Name  Qualification  Mobile   Adress
# 0  False  False          False    False   False
# 1  False  False          False    False   False
# 2  False  False          False    False   False
# 3  False  False          False    False   False
# 4  False  False          False    False    True
# 5  False  False          False    False    True
# 6  False  False          False    False   False
# 7  False  False          False    False   False
# 8  False  False          False     True   False
# 9  False  False          False     True   False

# %%
data.isnull().sum()
# Out:
# Sl_no            0
# Name             0
# Qualification    0
# Mobile           2
# Adress           2
# dtype: int64

# %%
df_dropped=data.dropna()

# %%
df_dropped
# Out:
#    Sl_no     Name Qualification       Mobile    Adress
# 0      1    Akash           MCA  7.899858e+09  Kokkada
# 1      2  Prakash           MCA  7.899858e+09  KOKKADA
# 2      3   Suresh           MBA  7.899858e+09  KOKKADA
# 3      4   Ramesh          MCOM  7.899858e+09  KOKKADA
# 6      7   M ayur           MCA  7.899858e+09  Nelyadi
# 7      8    Rampa          MCOM  7.899858e+09   Puttur

# %%
mean_val=data.mean()
mean_val
# Out:
# /tmp/ipykernel_9734/1393861138.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_val=data.mean()
# Sl_no      5.500000e+00
# Mobile     7.899858e+09
# dtype: float64

# %%
array=np.array([[1,1,1],[2,3,8],[3,5,7]])

# %%
array
# Out:
# array([[1, 1, 1],
#        [2, 3, 8],
#        [3, 5, 7]])

# %%
index_value=['Row1','Row2','Row3']
colum_value=['col1','col2','col3']

# %%
index_value
# Out:
# ['Row1', 'Row2', 'Row3']

# %%
df=pd.DataFrame(data=array,index=index_value,columns=colum_value)
df
# Out:
#       col1  col2  col3
# Row1     1     1     1
# Row2     2     3     8
# Row3     3     5     7

# %%
mean_val=data['Mobile'].mean()
data['Mobile']=data['Mobile'].fillna(mean_val)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mobile'
#
# The above exception was the direct cause of the following exception:
#
# ...
